# %% [markdown]
# <a href="https://colab.research.google.com/github/danilopinho75/Exercicios-SQL-Sirius/blob/main/SQL_Aula_4_Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !pip install jupysql
# Out:
# Collecting jupysql
#   Downloading jupysql-0.10.12-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from jupysql) (3.11.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from jupysql) (2.0.32)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from jupysql) (0.5.1)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from jupysql) (3.1.4)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.10/dist-packages (from jupysql) (20.11.0)
# Collecting jupysql-plugin>=0.4.2 (from jupysql)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Downloading ploomber_core-0.2.25-py3-none-any.whl.metadata (536 bytes)
# Collecting ploomber-extension (from jupysql)
#   Downloading ploomber_extension-0.1.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.2)
# Collecting posthog (from ploomber-core>=0.2.7->jupysql)
#   Downloading posthog-3.6.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->jupysql) (2.1.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->jupysql) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->jupysql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->jupysql) (3.0.3)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->ploomber-core>=0.2.7->jupysql)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog->ploomber-core>=0.2.7->jupysql)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2024.8.30)
# Downloading jupysql-0.10.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.9/95.9 kB 3.8 MB/s eta 0:00:00
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 9.8 MB/s eta 0:00:00
# Downloading ploomber_core-0.2.25-py3-none-any.whl (22 kB)
# Downloading ploomber_extension-0.1.1-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 kB 9.5 MB/s eta 0:00:00
# Downloading posthog-3.6.3-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: monotonic, backoff, posthog, ploomber-core, ploomber-extension, jupysql-plugin, jupysql
# Successfully installed backoff-2.2.1 jupysql-0.10.12 jupysql-plugin-0.4.5 monotonic-1.6 ploomber-core-0.2.25 ploomber-extension-0.1.1 posthog-3.6.3

# %%
# %load_ext sql
# Out:
# Deploy Streamlit apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# !wget https://rtvad.blob.core.windows.net/misc-data/northwind.sqlite3
# Out:
# --2024-09-05 22:54:43--  https://rtvad.blob.core.windows.net/misc-data/northwind.sqlite3
# Resolving rtvad.blob.core.windows.net (rtvad.blob.core.windows.net)... 20.60.132.100
# Connecting to rtvad.blob.core.windows.net (rtvad.blob.core.windows.net)|20.60.132.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 804864 (786K) [application/octet-stream]
# Saving to: ‘northwind.sqlite3’
#
# northwind.sqlite3   100%[===================>] 786.00K  --.-KB/s    in 0.06s
#
# 2024-09-05 22:54:43 (12.7 MB/s) - ‘northwind.sqlite3’ saved [804864/804864]

# %%
# %sql sqlite:///northwind.sqlite3
# Out:
# Connecting to 'sqlite:///northwind.sqlite3'

# %% [markdown]
# # Exercícios

# %% [markdown]
# Exercício 1:
# Listar todos os clientes e seus respectivos pedidos.

# %%
# %%sql
# SELECT * FROM Orders LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# | OrderID | CustomerID | EmployeeID |        OrderDate        |       RequiredDate      |       ShippedDate       | ShipVia | Freight |          ShipName         |    ShipAddress     | ShipCity | ShipRegion | ShipPostalCode | ShipCountry |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# |  10248  |   VINET    |     5      | 2014-07-04 08:00:00.000 | 2014-08-01 00:00:00.000 | 2014-07-16 00:00:00.000 |    3    |  32.38  | Vins et alcools Chevalier | 59 rue de l'Abbaye |  Reims   |    None    |     51100      |    France   |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+

# %%
# %%sql
# SELECT
#   *
# FROM Customers LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +--------------+
# |     name     |
# +--------------+
# |  Suppliers   |
# |   Shippers   |
# |  Employees   |
# |  Customers   |
# |    Orders    |
# |  Categories  |
# |   Products   |
# | OrderDetails |
# +--------------+

# %%
# %%sql
# SELECT * FROM Customers LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT * FROM Orders LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# | OrderID | CustomerID | EmployeeID |        OrderDate        |       RequiredDate      |       ShippedDate       | ShipVia | Freight |          ShipName         |    ShipAddress     | ShipCity | ShipRegion | ShipPostalCode | ShipCountry |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# |  10248  |   VINET    |     5      | 2014-07-04 08:00:00.000 | 2014-08-01 00:00:00.000 | 2014-07-16 00:00:00.000 |    3    |  32.38  | Vins et alcools Chevalier | 59 rue de l'Abbaye |  Reims   |    None    |     51100      |    France   |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+

# %%
# %%sql
# SELECT
#   C.CustomerID,
#   C.CompanyName,
#   C.ContactName,
#   O.OrderID
# FROM Customers C
# LEFT JOIN Orders O ON C.CustomerID = O.CustomerID;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+------------------------------------+--------------+---------+
# | CustomerID |            CompanyName             | ContactName  | OrderID |
# +------------+------------------------------------+--------------+---------+
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  10643  |
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  10692  |
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  10702  |
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  10835  |
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  10952  |
# |   ALFKI    |        Alfreds Futterkiste         | Maria Anders |  11011  |
# |   ANATR    | Ana Trujillo Emparedados y helados | Ana Trujillo |  10308  |
# |   ANATR    | Ana Trujillo Emparedados y helados | Ana Trujillo |  10625  |
# |   ANATR    | Ana Trujillo Emparedados y helados | Ana Trujillo |  10759  |
# |   ANATR    | Ana Trujillo Emparedados y helados | Ana Trujillo |  10926  |
# +------------+------------------------------------+--------------+---------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 2:
# Listar todos os pedidos feitos por um cliente específico.

# %%
# %%sql
# SELECT * FROM Orders LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# | OrderID | CustomerID | EmployeeID |        OrderDate        |       RequiredDate      |       ShippedDate       | ShipVia | Freight |          ShipName         |    ShipAddress     | ShipCity | ShipRegion | ShipPostalCode | ShipCountry |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# |  10248  |   VINET    |     5      | 2014-07-04 08:00:00.000 | 2014-08-01 00:00:00.000 | 2014-07-16 00:00:00.000 |    3    |  32.38  | Vins et alcools Chevalier | 59 rue de l'Abbaye |  Reims   |    None    |     51100      |    France   |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+

# %%
# %%sql
# SELECT * FROM Customers LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT
#   C.CustomerID,
#   O.OrderID,
#   O.OrderDate,
#   O.shippedDate
# FROM Customers C
# INNER JOIN Orders O ON C.CustomerID = O.CustomerID;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------+-------------------------+-------------------------+
# | CustomerID | OrderID |        OrderDate        |       ShippedDate       |
# +------------+---------+-------------------------+-------------------------+
# |   VINET    |  10248  | 2014-07-04 08:00:00.000 | 2014-07-16 00:00:00.000 |
# |   TOMSP    |  10249  | 2014-07-05 04:00:00.000 | 2014-07-10 00:00:00.000 |
# |   HANAR    |  10250  | 2014-07-08 15:00:00.000 | 2014-07-12 00:00:00.000 |
# |   VICTE    |  10251  | 2014-07-08 14:00:00.000 | 2014-07-15 00:00:00.000 |
# |   SUPRD    |  10252  | 2014-07-09 01:00:00.000 | 2014-07-11 00:00:00.000 |
# |   HANAR    |  10253  | 2014-07-10 08:00:00.000 | 2014-07-16 00:00:00.000 |
# |   CHOPS    |  10254  | 2014-07-11 02:00:00.000 | 2014-07-23 00:00:00.000 |
# |   RICSU    |  10255  | 2014-07-12 20:00:00.000 | 2014-07-15 00:00:00.000 |
# |   WELLI    |  10256  | 2014-07-15 22:00:00.000 | 2014-07-17 00:00:00.000 |
# |   HILAA    |  10257  | 2014-07-16 15:00:00.000 | 2014-07-22 00:00:00.000 |
# +------------+---------+-------------------------+-------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 3:
# Listar todos os produtos e seus respectivos fornecedores.

# %%
# %%sql
# SELECT * FROM Products LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# | ProductID | ProductName | SupplierID | CategoryID |  QuantityPerUnit   | UnitPrice | UnitsInStock | UnitsOnOrder | ReorderLevel | Discontinued |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# |     1     |     Chai    |     1      |     1      | 10 boxes x 20 bags |     18    |      39      |      0       |      10      |      0       |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+

# %%
# %%sql
# SELECT
#   *
# FROM Suppliers LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+
# | SupplierID |  CompanyName   |   ContactName    |    ContactTitle    |    Address     |  City  | Region | PostalCode | Country |     Phone      | Fax  | HomePage |
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+
# |     1      | Exotic Liquids | Charlotte Cooper | Purchasing Manager | 49 Gilbert St. | London |  None  |  EC1 4SD   |    UK   | (171) 555-2222 | None |   None   |
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+

# %%
# %%sql
# SELECT
#   P.ProductID,
#   P.ProductName,
#   P.SupplierID,
#   S.CompanyName
# FROM Products P
# INNER JOIN Suppliers S ON P.SupplierID = S.SupplierID
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+---------------------------------+------------+----------------------------+
# | ProductID |           ProductName           | SupplierID |        CompanyName         |
# +-----------+---------------------------------+------------+----------------------------+
# |     1     |               Chai              |     1      |       Exotic Liquids       |
# |     2     |              Chang              |     1      |       Exotic Liquids       |
# |     3     |          Aniseed Syrup          |     1      |       Exotic Liquids       |
# |     4     |   Chef Anton's Cajun Seasoning  |     2      | New Orleans Cajun Delights |
# |     5     |      Chef Anton's Gumbo Mix     |     2      | New Orleans Cajun Delights |
# |     6     |   Grandma's Boysenberry Spread  |     3      | Grandma Kelly's Homestead  |
# |     7     | Uncle Bob's Organic Dried Pears |     3      | Grandma Kelly's Homestead  |
# |     8     |    Northwoods Cranberry Sauce   |     3      | Grandma Kelly's Homestead  |
# |     9     |         Mishi Kobe Niku         |     4      |       Tokyo Traders        |
# |     10    |              Ikura              |     4      |       Tokyo Traders        |
# +-----------+---------------------------------+------------+----------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 4:
# Listar todos os produtos de uma determinada categoria.

# %%
# %%sql
# SELECT * FROM Products LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# | ProductID | ProductName | SupplierID | CategoryID |  QuantityPerUnit   | UnitPrice | UnitsInStock | UnitsOnOrder | ReorderLevel | Discontinued |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# |     1     |     Chai    |     1      |     1      | 10 boxes x 20 bags |     18    |      39      |      0       |      10      |      0       |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+

# %%
# %%sql
# SELECT CategoryID, CategoryName FROM Categories LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+--------------+
# | CategoryID | CategoryName |
# +------------+--------------+
# |     1      |  Beverages   |
# +------------+--------------+

# %%
# %%sql
# SELECT
#   P.ProductName,
#   C.CategoryName
# FROM Categories AS C
# LEFT JOIN Products AS P ON C.CategoryID = P.CategoryID
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------------------------+--------------+
# |        ProductName        | CategoryName |
# +---------------------------+--------------+
# |            Chai           |  Beverages   |
# |           Chang           |  Beverages   |
# |     Guaraná Fantástica    |  Beverages   |
# |       Sasquatch Ale       |  Beverages   |
# |       Steeleye Stout      |  Beverages   |
# |       Côte de Blaye       |  Beverages   |
# |      Chartreuse verte     |  Beverages   |
# |        Ipoh Coffee        |  Beverages   |
# | Laughing Lumberjack Lager |  Beverages   |
# |       Outback Lager       |  Beverages   |
# +---------------------------+--------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 5:
# Listar todos os pedidos entregues por determinada transportadora (explore a tabela para escolher uma transportadora)

# %%
# %%sql
# SELECT * FROM Orders LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# | OrderID | CustomerID | EmployeeID |        OrderDate        |       RequiredDate      |       ShippedDate       | ShipVia | Freight |          ShipName         |    ShipAddress     | ShipCity | ShipRegion | ShipPostalCode | ShipCountry |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# |  10248  |   VINET    |     5      | 2014-07-04 08:00:00.000 | 2014-08-01 00:00:00.000 | 2014-07-16 00:00:00.000 |    3    |  32.38  | Vins et alcools Chevalier | 59 rue de l'Abbaye |  Reims   |    None    |     51100      |    France   |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+

# %%
# %%sql
# SELECT * FROM Customers LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT DISTINCT CompanyName FROM Customers;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------------------------------+
# |            CompanyName             |
# +------------------------------------+
# |        Alfreds Futterkiste         |
# | Ana Trujillo Emparedados y helados |
# |      Antonio Moreno Taquería       |
# |          Around the Horn           |
# |           B's Beverages            |
# |         Berglunds snabbköp         |
# |      Blauer See Delikatessen       |
# |      Blondesddsl père et fils      |
# |              Bon app'              |
# |       Bottom-Dollar Markets        |
# +------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT
#   O.OrderID,
#   O.OrderDate,
#   C.CompanyName
# FROM Orders O
# INNER JOIN Customers C ON O.CustomerID = C.CustomerID
# WHERE C.CompanyName = "Blauer See Delikatessen"
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+-------------------------+-------------------------+
# | OrderID |        OrderDate        |       CompanyName       |
# +---------+-------------------------+-------------------------+
# |  10501  | 2015-04-09 19:00:00.000 | Blauer See Delikatessen |
# |  10509  | 2015-04-17 22:00:00.000 | Blauer See Delikatessen |
# |  10582  | 2015-06-27 22:00:00.000 | Blauer See Delikatessen |
# |  10614  | 2015-07-29 09:00:00.000 | Blauer See Delikatessen |
# |  10853  | 2016-01-27 03:00:00.000 | Blauer See Delikatessen |
# |  10956  | 2016-03-17 20:00:00.000 | Blauer See Delikatessen |
# |  11058  | 2016-04-29 04:00:00.000 | Blauer See Delikatessen |
# +---------+-------------------------+-------------------------+

# %% [markdown]
# Exercício 6: Listar todos os clientes que fizeram um pedido após uma determinada data (explore a tabela para descobrir os períodos e defina uma data)

# %%
# %%sql
#
# SELECT
#   C.CustomerID,
#   C.CompanyName,
#   O.OrderID,
#   O.OrderDate
# FROM Customers C
# LEFT JOIN Orders O ON C.CustomerID = O.CustomerID
# WHERE strftime('%Y', O.OrderDate) >= 2015
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+------------------------------------+---------+-------------------------+
# | CustomerID |            CompanyName             | OrderID |        OrderDate        |
# +------------+------------------------------------+---------+-------------------------+
# |   ALFKI    |        Alfreds Futterkiste         |  10643  | 2015-08-25 19:00:00.000 |
# |   ALFKI    |        Alfreds Futterkiste         |  10692  | 2015-10-03 05:00:00.000 |
# |   ALFKI    |        Alfreds Futterkiste         |  10702  | 2015-10-13 19:00:00.000 |
# |   ALFKI    |        Alfreds Futterkiste         |  10835  | 2016-01-15 20:00:00.000 |
# |   ALFKI    |        Alfreds Futterkiste         |  10952  | 2016-03-16 00:00:00.000 |
# |   ALFKI    |        Alfreds Futterkiste         |  11011  | 2016-04-09 09:00:00.000 |
# |   ANATR    | Ana Trujillo Emparedados y helados |  10308  | 2014-09-18 14:00:00.000 |
# |   ANATR    | Ana Trujillo Emparedados y helados |  10625  | 2015-08-08 15:00:00.000 |
# |   ANATR    | Ana Trujillo Emparedados y helados |  10759  | 2015-11-28 06:00:00.000 |
# |   ANATR    | Ana Trujillo Emparedados y helados |  10926  | 2016-03-04 16:00:00.000 |
# +------------+------------------------------------+---------+-------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 7:
# Listar todos os produtos que estão em estoque e que precisam ser reabastecidos

# %%
# %%sql
# SELECT * FROM Products;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+---------------------------------+------------+------------+---------------------+-----------+--------------+--------------+--------------+--------------+
# | ProductID |           ProductName           | SupplierID | CategoryID |   QuantityPerUnit   | UnitPrice | UnitsInStock | UnitsOnOrder | ReorderLevel | Discontinued |
# +-----------+---------------------------------+------------+------------+---------------------+-----------+--------------+--------------+--------------+--------------+
# |     1     |               Chai              |     1      |     1      |  10 boxes x 20 bags |     18    |      39      |      0       |      10      |      0       |
# |     2     |              Chang              |     1      |     1      |  24 - 12 oz bottles |     19    |      17      |      40      |      25      |      0       |
# |     3     |          Aniseed Syrup          |     1      |     2      | 12 - 550 ml bottles |     10    |      13      |      70      |      25      |      0       |
# |     4     |   Chef Anton's Cajun Seasoning  |     2      |     2      |    48 - 6 oz jars   |     22    |      53      |      0       |      0       |      0       |
# |     5     |      Chef Anton's Gumbo Mix     |     2      |     2      |       36 boxes      |   21.35   |      0       |      0       |      0       |      1       |
# |     6     |   Grandma's Boysenberry Spread  |     3      |     2      |    12 - 8 oz jars   |     25    |     120      |      0       |      25      |      0       |
# |     7     | Uncle Bob's Organic Dried Pears |     3      |     7      |   12 - 1 lb pkgs.   |     30    |      15      |      0       |      10      |      0       |
# |     8     |    Northwoods Cranberry Sauce   |     3      |     2      |   12 - 12 oz jars   |     40    |      6       |      0       |      0       |      0       |
# |     9     |         Mishi Kobe Niku         |     4      |     6      |   18 - 500 g pkgs.  |     97    |      29      |      0       |      0       |      1       |
# |     10    |              Ikura              |     4      |     8      |   12 - 200 ml jars  |     31    |      31      |      0       |      0       |      0       |
# +-----------+---------------------------------+------------+------------+---------------------+-----------+--------------+--------------+--------------+--------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT DISTINCT ReorderLevel FROM Products
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +--------------+
# | ReorderLevel |
# +--------------+
# |      10      |
# |      25      |
# |      0       |
# |      30      |
# |      5       |
# |      15      |
# |      20      |
# +--------------+

# %%
# %%sql
# SELECT
#   ProductName,
#   UnitsInStock,
#   ReorderLevel
# FROM Products
# WHERE ReorderLevel <> 0
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------------------------------+--------------+--------------+
# |           ProductName           | UnitsInStock | ReorderLevel |
# +---------------------------------+--------------+--------------+
# |               Chai              |      39      |      10      |
# |              Chang              |      17      |      25      |
# |          Aniseed Syrup          |      13      |      25      |
# |   Grandma's Boysenberry Spread  |     120      |      25      |
# | Uncle Bob's Organic Dried Pears |      15      |      10      |
# |          Queso Cabrales         |      22      |      30      |
# |              Konbu              |      24      |      5       |
# |           Genen Shouyu          |      39      |      5       |
# |             Pavlova             |      29      |      10      |
# |    Teatime Chocolate Biscuits   |      25      |      5       |
# +---------------------------------+--------------+--------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 8: Listar todos os funcionários e seus respectivos supervisores.

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +--------------+
# |     name     |
# +--------------+
# |  Suppliers   |
# |   Shippers   |
# |  Employees   |
# |  Customers   |
# |    Orders    |
# |  Categories  |
# |   Products   |
# | OrderDetails |
# +--------------+

# %%
# %%sql
# SELECT * FROM Employees LIMIT 1;
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+----------+-----------+----------------------+-----------------+-------------------------+-------------------------+--------------------+---------+--------+------------+---------+----------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# | EmployeeID | LastName | FirstName |        Title         | TitleOfCourtesy |        BirthDate        |         HireDate        |      Address       |   City  | Region | PostalCode | Country |   HomePhone    | Extension |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +------------+----------+-----------+----------------------+-----------------+-------------------------+-------------------------+--------------------+---------+--------+------------+---------+----------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |     1      | Davolio  |   Nancy   | Sales Representative |       Ms.       | 1966-12-08 00:00:00.000 | 2010-05-01 00:00:00.000 | 507 - 20th Ave. E. | Seattle |   WA   |   98122    |   USA   | (206) 555-9857 |    5467   | b'\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\x14\x00!\x00\xff\xff\xff\xffBitmap Image\x00Paint.Picture\x00\x01\x05\x00\x00\x02\x00\x00\x00\x07\x00\x00\x00PBrush\x00\x00\x00\x00\x00\x00\x00\x00\x00 T\x00\x00BM T\x00\x00\x00\x00\x00\x00v\x00\x00\x00(\x00\x00\x00\xc0\x00\x00\x00\xdf\x00\x00\x00\x01\x00\x04\x00\x00\x00\x00\x00\xa0S\t\t\x00\x00\n\x00\x90\t\x00\x00\x00\x00\t\t\xa0\x9a\x90\x0b\t\x00\n\x90\xa0\x00\x00\x00\x0f\xff\xef\xff\xff\xff\xff\xff\xff\xff\xff\xcb\x9c\xfc\xfe\xfa\xff\xff\xff\xff\xed\xff\xfe\xde\xff\xde\xfe\xfc\xff\xff\xda\xda\x00\xd9\x00\x00\x90\t\x00\x90\x00\x00\x00\x00\t\n\x00\t\x0b\xc0\x00\t\x00\x90\x00\x00\x00\n\x00\xac\xa0\xe0\xe0\xe0\xf0\xe9\xca\x90\x00\xa9\xcb\x0c\x00\x00\x90\x90\xe0\x00\x00\t\t\x0b\x00\x00\xd0\t\x00\x90\x00\x00\t\x00\x00\x9a\x00\x0f\xff\xff\xff\xff\xff\xfe\xff\xff\xff\xff\xfc\xad\xeb\xdb\xdf\xdf\xdf\xff\xff\xff\xff\xef\xed\xff\xfe\xff\xff\xff\xfe\xfc\xaf\x0c\x9a\n\r\x00\x00\x9a\x00\x00\x00\x00\x00\x00\x00\t\t\n\x00\x0b\x00\x9a\x90\x00\t\x00\x00\x90\x0c\t\x00\x90\t\x00\xfa\x90\xad\xa0\x00\x90\xb0\x0b\x00\x00\x00\x00\x90\x00\t\x00\x00\x00\x90\t\xa9\xb0\t\x00\x9a\x00\x00\x00\x00\xc0\x00\xbf\xff\xff\xff\xfe\xff\xff\xff\xff\xff\xff\xcf\x9f\xbc\xbe\xfb\xff\xeb\xff\xff\xff\xfe\xfd\xff\xfe\xfd\xff\xcf\xfe\xff\xf9\xbc\x0b\x00\x90\x90\x00\x90\x00\t\x00\x00\x00\x00\x00\x00\x90\x00\x00\x90\x90\t\xa0\xc0\xb0\x00\x00\xb0\x00\t\xa0\x0e\x0e\x0e\x0e\xfc\xad\xa0\xc9\x00\x00\xcb\x00\x90\x00\x00\x9a\x9a\t\xa0\x00\xb0\t\x00\x90\x90\r\x00\xa9\t\x00\t\t\n\x00\x00\xff\xff\xff\xfe\xff\xfe\xff\xff\xff\xff\xff\xf0\xf0\xff\xdf\xed\xad\xfd\xff\xff\xff\xff\xfe\xfe\xfd\xef\xef\xfc\xfd\xef\xec\x0f\x0c\x9a\xc0\n\x00\xa0\x90\x00\x00\x00\x90\x00\x00\x00\t\n\x90\n\x00\x00\x90\x90\x00\n\x00\x00\x0c\xa0\x0c\t\x00\x90\x90\xf9\x00\xda\x00\x9a\x90\x00\xda\x00\xd0\x00\x00\t\xc0\x90\x00\x00\x90\xb0\x00\xa9\xa9\xb0\x90\x00\x00\x00\xac\x00\x00\x0b\xff\xef\xff\xff\xff\xff\xff\xff\xff\xff\xed\xa9\xdf\x0f\xf9\xff\xff\xff\xf0\xff\xff\xff\xff\xfd\xfe\xff\xde\xff\xef\xdf\xf9\xa9\xa0\t\t\t\x00\x90\x00\x90\x00\x00\x00\x00\x00\t\n\x90\x00\x90\x9a\x90\x00\xa9\r\t\x00\x00\xa9\x00\x0b\x0e\x0c\xac\xa0\xfa\xe9\xa9\xca\x00\n\x99\xa9\x0b\x00\x00\x00\x90\xb0\x00\x90\x90\x00\t\x00\x90\xd0\x00\t\xa9\x00\x00\x90\x00\x00\x9f\xff\xff\xff\xff\xff\xff\xef\xff\xff\xfe\xda\xde\xbc\xfd\xef\xfd\xad\xad\xff\xff\xff\xff\xff\xef\xef\xcb\xef\xde\xdb\xef\xca\xd0\xd0\xe0\n\x00\x00\x00\x90\x00\x00\x00\x00\x00\x00\x90\t\x00\x90\x00\x00\x00\t\x00\n\x00\x00\x90\x00\x00\x00\x00\x9a\x90\r\xf0\x90\xca\x90\t\t\x0e\x90\x90\x0b\x00\t\n\x90\t\x00\x00\x90\xb0\t\xa0\x9a\x90\x90\x90\x00\t\x0b\x00\t\xff\xff\xff\xff\xff\xfe\xff\xff\xff\xff\xfd\t\xe9\xcf\xbf\xbf\x0f\xff\xff\xef\xfd\xef\xff\xff\xff\xfd\xff\xdf\xeb\xfe\xfd\xa9\x0b\n\x90\x90\n\x90\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x90\x90\x00\x90\xa9\t\x00\n\x00\x00\xac\xb0\x0b\x0c\x0e\n\xf0\xf0\xbc\t\x00\x00\t\xad\xa9\t\x00\x00\t\x0f\x00\x00\x90\t\t\x00\x99\t\xa9\xa0\x90\x00\x00\x00\x00\x00\xff\xfe\xff\xff\xef\xff\xef\xfe\xff\xff\xea\x9e\x9f\xbf\xde\xdf\xff\xdf\xff\xdf\xff\xff\xcf\xff\xff\xef\xef\xed\xfc\xfd\xef\xc0\x00\xd0\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x90\t\x00\n\x00\x90\t\x00\x00\xb0\t\x00\x00\x90\x00\xc0\n\t\xc0\xff\x0f\x0b\xca\x0b\n\x00\t\x0f\n\x9a\x90\x00\x90\xb0\x90\t\x00\t\x00\x00\xb0\xd0\x90\xa9\x00\x00\x9a\x00\x0b\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xd0\xf9\xe9\xf0\xfb\xef\x0f\xaf\xcb\xfe\xff\xdf\xff\xff\xff\xff\xdf\xfa\xff\ ...
# |            |          |           |                      |                 |                         |                         |      Apt. 2A       |         |        |            |         |                |           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +------------+----------+-----------+----------------------+-----------------+-------------------------+-------------------------+--------------------+---------+--------+------------+---------+----------------+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
# %%sql
# SELECT DISTINCT Title FROM Employees
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +--------------------------+
# |          Title           |
# +--------------------------+
# |   Sales Representative   |
# |  Vice President, Sales   |
# |      Sales Manager       |
# | Inside Sales Coordinator |
# +--------------------------+

# %%
# %%sql
#
# SELECT FirstName, LastName, Title FROM Employees
# WHERE FirstName = ""
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+----------+----------------------+
# | FirstName | LastName |        Title         |
# +-----------+----------+----------------------+
# |  Michael  |  Suyama  | Sales Representative |
# +-----------+----------+----------------------+

# %%
# %%sql
# SELECT * FROM Customers LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT
#   EmployeeID,
#   LastName,
#   FirstName
# FROM Employees
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+-----------+-----------+
# | EmployeeID |  LastName | FirstName |
# +------------+-----------+-----------+
# |     1      |  Davolio  |   Nancy   |
# |     2      |   Fuller  |   Andrew  |
# |     3      | Leverling |   Janet   |
# |     4      |  Peacock  |  Margaret |
# |     5      |  Buchanan |   Steven  |
# |     6      |   Suyama  |  Michael  |
# |     7      |    King   |   Robert  |
# |     8      |  Callahan |   Laura   |
# |     9      | Dodsworth |    Anne   |
# +------------+-----------+-----------+

# %%
# %%sql
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+-----------+-----------+--------------------+---------------------+
# | EmployeeID |  LastName | FirstName | SupervisorLastName | SupervisorFirstName |
# +------------+-----------+-----------+--------------------+---------------------+
# |     1      |  Davolio  |   Nancy   |       Fuller       |        Andrew       |
# |     2      |   Fuller  |   Andrew  |        None        |         None        |
# |     3      | Leverling |   Janet   |       Fuller       |        Andrew       |
# |     4      |  Peacock  |  Margaret |       Fuller       |        Andrew       |
# |     5      |  Buchanan |   Steven  |       Fuller       |        Andrew       |
# |     6      |   Suyama  |  Michael  |      Buchanan      |        Steven       |
# |     7      |    King   |   Robert  |      Buchanan      |        Steven       |
# |     8      |  Callahan |   Laura   |       Fuller       |        Andrew       |
# |     9      | Dodsworth |    Anne   |      Buchanan      |        Steven       |
# +------------+-----------+-----------+--------------------+---------------------+

# %% [markdown]
# Exercício 9: Listar todos os fornecedores e seus respectivos produtos.

# %%
# %%sql
# SELECT * FROM Suppliers LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+
# | SupplierID |  CompanyName   |   ContactName    |    ContactTitle    |    Address     |  City  | Region | PostalCode | Country |     Phone      | Fax  | HomePage |
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+
# |     1      | Exotic Liquids | Charlotte Cooper | Purchasing Manager | 49 Gilbert St. | London |  None  |  EC1 4SD   |    UK   | (171) 555-2222 | None |   None   |
# +------------+----------------+------------------+--------------------+----------------+--------+--------+------------+---------+----------------+------+----------+

# %%
# %%sql
# SELECT * FROM Products LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# | ProductID | ProductName | SupplierID | CategoryID |  QuantityPerUnit   | UnitPrice | UnitsInStock | UnitsOnOrder | ReorderLevel | Discontinued |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+
# |     1     |     Chai    |     1      |     1      | 10 boxes x 20 bags |     18    |      39      |      0       |      10      |      0       |
# +-----------+-------------+------------+------------+--------------------+-----------+--------------+--------------+--------------+--------------+

# %%
# %%sql
# SELECT
#   S.SupplierID,
#   S.CompanyName,
#   P.ProductID,
#   P.ProductName
# FROM Suppliers S
# LEFT JOIN Products P ON S.SupplierID = P.SupplierID
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+------------------------------------+-----------+---------------------------+
# | SupplierID |            CompanyName             | ProductID |        ProductName        |
# +------------+------------------------------------+-----------+---------------------------+
# |     18     |     Aux joyeux ecclésiastiques     |     38    |       Côte de Blaye       |
# |     18     |     Aux joyeux ecclésiastiques     |     39    |      Chartreuse verte     |
# |     16     |         Bigfoot Breweries          |     34    |       Sasquatch Ale       |
# |     16     |         Bigfoot Breweries          |     35    |       Steeleye Stout      |
# |     16     |         Bigfoot Breweries          |     67    | Laughing Lumberjack Lager |
# |     5      | Cooperativa de Quesos 'Las Cabras' |     11    |       Queso Cabrales      |
# |     5      | Cooperativa de Quesos 'Las Cabras' |     12    | Queso Manchego La Pastora |
# |     27     |         Escargots Nouveaux         |     58    |   Escargots de Bourgogne  |
# |     1      |           Exotic Liquids           |     1     |            Chai           |
# |     1      |           Exotic Liquids           |     2     |           Chang           |
# +------------+------------------------------------+-----------+---------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Exercício 10:
# Listar o total de vendas por cliente.

# %%
# %%sql
# SELECT * FROM Orders LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# | OrderID | CustomerID | EmployeeID |        OrderDate        |       RequiredDate      |       ShippedDate       | ShipVia | Freight |          ShipName         |    ShipAddress     | ShipCity | ShipRegion | ShipPostalCode | ShipCountry |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+
# |  10248  |   VINET    |     5      | 2014-07-04 08:00:00.000 | 2014-08-01 00:00:00.000 | 2014-07-16 00:00:00.000 |    3    |  32.38  | Vins et alcools Chevalier | 59 rue de l'Abbaye |  Reims   |    None    |     51100      |    France   |
# +---------+------------+------------+-------------------------+-------------------------+-------------------------+---------+---------+---------------------------+--------------------+----------+------------+----------------+-------------+

# %%
# %%sql
# SELECT * FROM Customers LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# | CustomerID |     CompanyName     | ContactName  |     ContactTitle     |    Address    |  City  | Region | PostalCode | Country |    Phone    |     Fax     |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+
# |   ALFKI    | Alfreds Futterkiste | Maria Anders | Sales Representative | Obere Str. 57 | Berlin |  None  |   12209    | Germany | 030-0074321 | 030-0076545 |
# +------------+---------------------+--------------+----------------------+---------------+--------+--------+------------+---------+-------------+-------------+

# %%
# %%sql
# SELECT * FROM OrderDetails LIMIT 1
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +---------+-----------+-----------+----------+----------+
# | OrderID | ProductID | UnitPrice | Quantity | Discount |
# +---------+-----------+-----------+----------+----------+
# |  10248  |     11    |     14    |    12    |   0.0    |
# +---------+-----------+-----------+----------+----------+

# %%
# %%sql
# SELECT
#   C.CustomerID,
#   C.CompanyName,
#   SUM(OD.UnitPrice * OD.Quantity) AS TotalSales
# FROM Customers C
# INNER JOIN Orders O ON C.CustomerID = O.CustomerID
# INNER JOIN OrderDetails OD ON O.OrderID = OD.OrderID
# GROUP BY C.CustomerID
# Out:
# Running query in 'sqlite:///northwind.sqlite3'
# +------------+------------------------------------+--------------------+
# | CustomerID |            CompanyName             |     TotalSales     |
# +------------+------------------------------------+--------------------+
# |   ALFKI    |        Alfreds Futterkiste         |       4596.2       |
# |   ANATR    | Ana Trujillo Emparedados y helados |      1402.95       |
# |   ANTON    |      Antonio Moreno Taquería       | 7515.349999999999  |
# |   AROUT    |          Around the Horn           |      13806.5       |
# |   BERGS    |         Berglunds snabbköp         | 26968.149999999998 |
# |   BLAUS    |      Blauer See Delikatessen       |       3239.8       |
# |   BLONP    |      Blondesddsl père et fils      |      19088.0       |
# |   BOLID    |     Bólido Comidas preparadas      |       5297.8       |
# |   BONAP    |              Bon app'              |      23850.95      |
# |   BOTTM    |       Bottom-Dollar Markets        |      22607.7       |
# +------------+------------------------------------+--------------------+
# Truncated to displaylimit of 10.
